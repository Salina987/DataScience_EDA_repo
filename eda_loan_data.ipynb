# %%
import numpy as np
import pandas as pd     
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("loan.csv")
data.head()
# Out:
#    Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 0           0  LP002305  Female      No          0      Graduate
# 1           1  LP001715    Male     Yes         3+  Not Graduate
# 2           2  LP002086  Female     Yes          0      Graduate
# 3           3  LP001136    Male     Yes          0  Not Graduate
# 4           4  LP002529    Male     Yes          2      Graduate
#
#   Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0            No             4547                0.0       115.0
# 1           Yes             5703                0.0       130.0
# 2            No             4333             2451.0       110.0
# 3           Yes             4695                0.0        96.0
# 4            No             6700             1750.0       230.0
#
#    Loan_Amount_Term  Credit_History Property_Area  Loan_Status
# 0             360.0             1.0     Semiurban            1
# ...

# %%
data.shape
# Out:
# (491, 14)

# %%
data["Loan_Status"].value_counts()
# Out:
# Loan_Status
# 1    343
# 0    148
# Name: count, dtype: int64

# %%
data["Loan_Status"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
data.describe()
# Out:
#        Unnamed: 0  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count  491.000000       491.000000         491.000000  475.000000
# mean   245.000000      5401.189409        1589.730998  145.014737
# std    141.883755      6419.427177        2919.320624   86.310534
# min      0.000000       150.000000           0.000000   17.000000
# 25%    122.500000      2923.500000           0.000000  100.000000
# 50%    245.000000      3865.000000        1229.000000  126.000000
# 75%    367.500000      5705.500000        2251.500000  162.000000
# max    490.000000     81000.000000       41667.000000  700.000000
#
#        Loan_Amount_Term  Credit_History  Loan_Status
# count        478.000000      448.000000   491.000000
# mean         341.297071        0.848214     0.698574
# std           66.964051        0.359214     0.459345
# min           12.000000        0.000000     0.000000
# 25%          360.000000        1.000000     0.000000
# ...

# %%
data["ApplicantIncome"].hist()
# Out:
# <Axes: >

# %%
sns.histplot(data["ApplicantIncome"])
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Count'>

# %%
sns.histplot(data["CoapplicantIncome"])
# Out:
# <Axes: xlabel='CoapplicantIncome', ylabel='Count'>

# %%
# numerical
# categorical[yes/no], male female
# ordinal data[urban.smiurban , rular]

# %%
sns.boxplot(data["CoapplicantIncome"])
# Out:
# <Axes: ylabel='CoapplicantIncome'>

# %%
sns.boxplot(data["ApplicantIncome"])
# Out:
# <Axes: ylabel='ApplicantIncome'>

# %%
##categorical data (univariate analysis )
sns.countplot(x="Married",data=data)
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
sns.countplot(x="Self_Employed",data=data)
# Out:
# <Axes: xlabel='Self_Employed', ylabel='count'>

# %%
sns.countplot(data=data,x="Gender")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=data,x="Education")
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
##bivarial data analysis
#Categorical vs Target

# %%
sns.countplot(data=data, x="Gender", hue="Loan_Status")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=data, x="Property_Area", hue="Loan_Status")
# Out:
# <Axes: xlabel='Property_Area', ylabel='count'>

# %% [markdown]
# #Numerical data vs Target

# %%
data["ApplicantIncome"].describe()
# Out:
# count      491.000000
# mean      5401.189409
# std       6419.427177
# min        150.000000
# 25%       2923.500000
# 50%       3865.000000
# 75%       5705.500000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %%
bins=[0,3000,4000,6000,81000]
group=["low","Average","Good","High"]

data["ApplicantIncomeCat"]=pd.cut(data["ApplicantIncome"],bins,labels=group)

# %%
data[["ApplicantIncome","ApplicantIncomeCat"]]
# Out:
#      ApplicantIncome ApplicantIncomeCat
# 0               4547               Good
# 1               5703               Good
# 2               4333               Good
# 3               4695               Good
# 4               6700               High
# ..               ...                ...
# 486             9833               High
# 487             3812            Average
# 488            14583               High
# 489             1836                low
# 490             2785                low
#
# [491 rows x 2 columns]

# %%
sns.countplot(data=data, x="ApplicantIncomeCat", hue="Loan_Status")
# Out:
# <Axes: xlabel='ApplicantIncomeCat', ylabel='count'>

# %%
##Missing Values Imputation
##HAndling Categorical Values
##data normalization
##removing Outlier
##Inconsistent Data
##Feature Engineering

# %%
#label encoding

# m f
# 0 1

# %%
##data normalization
x=[20,30,40,560]
##Outlier Handling 

##Standardization/Normaliation
age=20,22,25
0.2 ,0.21,0.25
salary=20000,30000,40000
0.3,0.4,0.5

future= age + salary
##future=0.5+0.3=0.8

# %%
##loan amount term= 50000
##term =50

# -->Emi=loan amount/term
#       =1000

# %%
##Mean Median Mode
data["Gender"].fillna(data["Gender"].mode()[0], inplace=True)
data["Married"].fillna(data["Married"].mode()[0], inplace=True)
data["Dependents"].fillna(data["Dependents"].mode()[0], inplace=True)
data["Self_Employed"].fillna(data["Self_Employed"].mode()[0], inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0             0
# Loan_ID                0
# Gender                 0
# Married                0
# Dependents             0
# Education              0
# Self_Employed          0
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount            16
# Loan_Amount_Term      13
# Credit_History         0
# Property_Area          0
# Loan_Status            0
# ApplicantIncomeCat     0
# dtype: int64

# %%
data["LoanAmount"].hist()
# Out:
# <Axes: >

# %%
data["LoanAmount"].fillna(data["LoanAmount"].median(), inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21332\1384821406.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["LoanAmount"].fillna(data["LoanAmount"].median(), inplace=True)

# %%
data["Loan_Amount_Term"].hist()
# Out:
# <Axes: >

# %%
data["Loan_Amount_Term"].fillna(data["Loan_Amount_Term"].mode(), inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21332\3877655673.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Loan_Amount_Term"].fillna(data["Loan_Amount_Term"].mode(), inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0            0
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# ApplicantIncomeCat    0
# dtype: int64

# %%
##Handling Outliers
